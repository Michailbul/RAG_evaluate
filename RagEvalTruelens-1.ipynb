# %%
#!pip install trulens_eval llama_index llama_hub html2text llmsherpa tenacity protobuf==3.20

# %%
from trulens_eval import Tru

tru = Tru(database_redact_keys = True)
# Out:
# Package protobuf is installed but has a version conflict:
# 	(protobuf 3.20.0 (c:\users\28263\anaconda3\lib\site-packages), Requirement.parse('protobuf>=4.23.2'))
#
# This package is optional for trulens_eval so this may not be a problem but if
# you need to use the related optional features and find there are errors, you
# will need to resolve the conflict:
#
#     ```bash
#     pip install 'protobuf>=4.23.2'
#     ```
#
# If you are running trulens_eval in a notebook, you may need to restart the
# kernel after resolving the conflict. If your distribution is in a bad place
# beyond this package, you may need to reinstall trulens_eval so that all of the
# dependencies get installed and hopefully corrected:
#
#     ```bash
#     pip uninstall -y trulens_eval
#     pip install trulens_eval
#     ```
#
# Package watchdog is installed but has a version conflict:
# 	(watchdog 2.1.6 (c:\users\28263\anaconda3\lib\site-packages), Requirement.parse('watchdog>=3.0.0'))
#
# This package is optional for trulens_eval so this may not be a problem but if
# you need to use the related optional features and find there are errors, you
# will need to resolve the conflict:
#
#     ```bash
#     pip install 'watchdog>=3.0.0'
#     ```
#
# If you are running trulens_eval in a notebook, you may need to restart the
# kernel after resolving the conflict. If your distribution is in a bad place
# beyond this package, you may need to reinstall trulens_eval so that all of the
# dependencies get installed and hopefully corrected:
#
#     ```bash
#     pip uninstall -y trulens_eval
#     pip install trulens_eval
#     ```
#
# Package scikit-learn is installed but has a version conflict:
# 	(scikit-learn 1.2.2 (c:\users\28263\anaconda3\lib\site-packages), Requirement.parse('scikit-learn>=1.3.1'))
#
# This package is optional for trulens_eval so this may not be a problem but if
# you need to use the related optional features and find there are errors, you
# will need to resolve the conflict:
#
#     ```bash
#     pip install 'scikit-learn>=1.3.1'
#     ```
#
# If you are running trulens_eval in a notebook, you may need to restart the
# kernel after resolving the conflict. If your distribution is in a bad place
# beyond this package, you may need to reinstall trulens_eval so that all of the
# dependencies get installed and hopefully corrected:
#
#     ```bash
#     pip uninstall -y trulens_eval
#     pip install trulens_eval
#     ```
#
# Package nbconvert is installed but has a version conflict:
# 	(nbconvert 6.5.4 (c:\users\28263\anaconda3\lib\site-packages), Requirement.parse('nbconvert>=7.14.2'))
#
# This package is optional for trulens_eval so this may not be a problem but if
# you need to use the related optional features and find there are errors, you
# will need to resolve the conflict:
#
#     ```bash
#     pip install 'nbconvert>=7.14.2'
#     ```
#
# If you are running trulens_eval in a notebook, you may need to restart the
# kernel after resolving the conflict. If your distribution is in a bad place
# beyond this package, you may need to reinstall trulens_eval so that all of the
# dependencies get installed and hopefully corrected:
#
#     ```bash
#     pip uninstall -y trulens_eval
#     pip install trulens_eval
#     ```
#
# Package docarray is installed but has a version conflict:
# 	(docarray 0.38.0 (c:\users\28263\anaconda3\lib\site-packages), Requirement.parse('docarray>=0.39.1'))
#
# This package is optional for trulens_eval so this may not be a problem but if
# you need to use the related optional features and find there are errors, you
# will need to resolve the conflict:
#
#     ```bash
#     pip install 'docarray>=0.39.1'
#     ```
#
# If you are running trulens_eval in a notebook, you may need to restart the
# kernel after resolving the conflict. If your distribution is in a bad place
# beyond this package, you may need to reinstall trulens_eval so that all of the
# dependencies get installed and hopefully corrected:
#
#     ```bash
#     pip uninstall -y trulens_eval
#     pip install trulens_eval
#     ```
#
# Package ipywidgets is installed but has a version conflict:
# 	(ipywidgets 7.6.5 (c:\users\28263\anaconda3\lib\site-packages), Requirement.parse('ipywidgets>=8.0.6'))
#
# This package is optional for trulens_eval so this may not be a problem but if
# you need to use the related optional features and find there are errors, you
# will need to resolve the conflict:
#
#     ```bash
#     pip install 'ipywidgets>=8.0.6'
#     ```
#
# If you are running trulens_eval in a notebook, you may need to restart the
# kernel after resolving the conflict. If your distribution is in a bad place
# beyond this package, you may need to reinstall trulens_eval so that all of the
# dependencies get installed and hopefully corrected:
#
#     ```bash
#     pip uninstall -y trulens_eval
#     pip install trulens_eval
#     ```
#
# Package datasets is installed but has a version conflict:
# 	(datasets 2.10.1 (c:\users\28263\anaconda3\lib\site-packages), Requirement.parse('datasets>=2.12.0'))
#
# This package is optional for trulens_eval so this may not be a problem but if
# you need to use the related optional features and find there are errors, you
# will need to resolve the conflict:
#
#     ```bash
#     pip install 'datasets>=2.12.0'
#     ```
#
# If you are running trulens_eval in a notebook, you may need to restart the
# kernel after resolving the conflict. If your distribution is in a bad place
# beyond this package, you may need to reinstall trulens_eval so that all of the
# dependencies get installed and hopefully corrected:
#
#     ```bash
#     pip uninstall -y trulens_eval
#     pip install trulens_eval
#     ```
#
# c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\utils\imports.py:489: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   return self.imp(name, globals, locals, fromlist, level)
# 🦑 Tru initialized with db url sqlite:///default.sqlite .
# 🔒 Secret keys will not be included in the database.

# %%
from llama_index.readers.smart_pdf_loader import SmartPDFLoader

llmsherpa_api_url = "https://readers.llmsherpa.com/api/document/developer/parseDocument?renderFormat=all"
pdf_loader = SmartPDFLoader(llmsherpa_api_url=llmsherpa_api_url)

documents = pdf_loader.load_data("https://www.iii.org/sites/default/files/docs/pdf/Insurance_Handbook_20103.pdf")

# %%
from langchain.llms import OpenAI

llm = OpenAI(model="gpt-3.5-turbo", temperature=0.5)

# %%
from llama_index.core.schema import Document
from llama_index.core.indices.vector_store.base import VectorStoreIndex
#join all the documents
document = Document(text = "/n/n".join([doc.text for doc in documents]))

from llama_index.core.indices.service_context import ServiceContext 
from llama_index.embeddings.huggingface import HuggingFaceEmbedding 
from langchain.embeddings.openai import OpenAIEmbeddings
import os

from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import Settings

embed_model = OpenAIEmbedding()

Settings.embed_model = OpenAIEmbeddings(
    model='text-embedding-ada-002',
    openai_api_key=os.environ["OPENAI_API_KEY"]
)
Settings.llm=OpenAI(model = 'text-davinci-003', temperature = 0)

# service_context = ServiceContext.from_defaults(
#     llm=llm,
#     embed_model =embed_model,
# )

#from llama_index import VectorStoreIndex 
index = VectorStoreIndex.from_documents([document])


from llama_index.core import PromptTemplate 

system_prompt = PromptTemplate(
    "We have provided some context information bellow that you may use, \n"
    "---------------------------------------\n"
    "{context_str}"
    "---------------------------------------\n"
    "Please answer the question {query_str}\n"
)

rag_basic = index.as_query_engine(text_qa_template=system_prompt)

# %%
honest_evals = [
    "What are the typical coverage options for homeowners insurance",
    "What are the requirements for long term care insurance to start",
    "How much in losses does fraud account for in property and casualty insurance",
    "What was the most costly earthquake in US History for insurers"
]

# %% [markdown]
# # Set up evaluation

# %%
import os 
import numpy as np
from trulens_eval import Feedback


from trulens_eval.feedback.provider import OpenAI as fOpenAI

openai = fOpenAI()


#Answer relevance

#on_input_output() --> what text we wanna evaluate this feedback function on. This text may be located in a
# variety places. Here we use helper funciton
qa_relevance = (
    Feedback(openai.relevance_with_cot_reasons, 
                        name = "Answer Relevance").on_input_output()
)


from trulens_eval import TruLlama

#context relevance
#We wanna look at each peaice of context that we are treating and how relevant it is with users queary
# ,on(Truelama) --> where the context is located in a of llama index app
#.aggregate --> since we are gonna measure relevance of multiple peices of context -- use mean
from trulens_eval import TruLlama
qs_relevance = (
    Feedback(openai.qs_relevance_with_cot_reasons, name = "Context Relevance")
    .on_input()
    .on(TruLlama.select_source_nodes().node.text)
    .aggregate(np.mean)
)

#embedding distance


# embedding distance
from langchain.embeddings.openai import OpenAIEmbeddings
from trulens_eval.feedback import Embeddings



model_name = 'text-embedding-ada-002'
Settings.embed_model = OpenAIEmbedding()

# embed_model = OpenAIEmbeddings(
#     model=model_name,
#     openai_api_key=os.environ["OPENAI_API_KEY"]
# )


#groundedness

from trulens_eval.feedback import Groundedness

grounded = Groundedness(groundedness_provider=openai)

f_groundedness = (
    Feedback(grounded.groundedness_measure_with_cot_reasons, name="Groundedness")
        .on(TruLlama.select_source_nodes().node.text.collect()) #context
        .on_output()#output 
        .aggregate(grounded.grounded_statements_aggregator)#aggregator
)

honest_feedbacks = [qa_relevance, qs_relevance, f_groundedness]

#honest_feedbacks = [qa_relevance, qs_relevance, f_embed_dist, f_groundedness]

# embed = Embeddings(embed_model=embed_model)

# f_embed_dist = (
#     Feedback(embed.cosine_distance)
#     .on_input()
#     .on(TruLlama.select_source_nodes().node.text)
# )
# Out:
# ✅ In Answer Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Answer Relevance, input response will be set to __record__.main_output or `Select.RecordOutput` .
# ✅ In Context Relevance, input question will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Context Relevance, input statement will be set to __record__.app.query.rets.source_nodes[:].node.text .
# ✅ In Groundedness, input source will be set to __record__.app.query.rets.source_nodes[:].node.text.collect() .
# ✅ In Groundedness, input statement will be set to __record__.main_output or `Select.RecordOutput` .

# %%
from trulens_eval import TruLlama
tru_recorder_rag_basic = TruLlama(
        rag_basic,
        app_id='1) Basic RAG - Honest Eval',
        feedbacks=honest_feedbacks
    )

# %%
# Run evaluation on sample questions
with tru_recorder_rag_basic as recording:
    for question in honest_evals:
        response = rag_basic.query(question)
# Out:
# Error calling wrapped function wrapped_llm_predict.
# Traceback (most recent call last):
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 733, in tru_wrapper
#     rets, cost = Endpoint.track_all_costs_tally(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 496, in track_all_costs_tally
#     result, cbs = Endpoint.track_all_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 477, in track_all_costs
#     return Endpoint._track_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 574, in _track_costs
#     result: T = __func(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\llms\callbacks.py", line 219, in wrapped_llm_predict
#     f_return_val = f(_self, *args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\llms\langchain\base.py", line 90, in complete
#     output_str = self._llm.predict(prompt, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\_api\deprecation.py", line 145, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 1013, in predict
#     return self(text, stop=_stop, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\_api\deprecation.py", line 145, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 972, in __call__
#     self.generate(
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 714, in generate
#     output = self._generate_helper(
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 578, in _generate_helper
#     raise e
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 565, in _generate_helper
#     self._generate(
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_community\llms\openai.py", line 460, in _generate
#     response = completion_with_retry(
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_community\llms\openai.py", line 115, in completion_with_retry
#     return llm.client.create(**kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 668, in tru_wrapper
#     response = func(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\_utils\_utils.py", line 275, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\resources\completions.py", line 516, in create
#     return self._post(
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\_base_client.py", line 1208, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\_base_client.py", line 897, in request
#     return self._request(
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\_base_client.py", line 988, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.NotFoundError: Error code: 404 - {'error': {'message': 'The model `text-davinci-003` has been deprecated, learn more here: https://platform.openai.com/docs/deprecations', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
#
# Error calling wrapped function get_response.
# Traceback (most recent call last):
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 733, in tru_wrapper
#     rets, cost = Endpoint.track_all_costs_tally(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 496, in track_all_costs_tally
#     result, cbs = Endpoint.track_all_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 477, in track_all_costs
#     return Endpoint._track_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 574, in _track_costs
#     result: T = __func(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\response_synthesizers\refine.py", line 163, in get_response
#     response = self._give_response_single(
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\response_synthesizers\refine.py", line 217, in _give_response_single
#     program(
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\response_synthesizers\refine.py", line 68, in __call__
#     answer = self._llm.predict(
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\llms\llm.py", line 257, in predict
#     response = self.complete(formatted_prompt, formatted=True)
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 831, in tru_wrapper
#     handle_done(rets=rets)
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 800, in handle_done
#     raise error
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 733, in tru_wrapper
#     rets, cost = Endpoint.track_all_costs_tally(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 496, in track_all_costs_tally
#     result, cbs = Endpoint.track_all_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 477, in track_all_costs
#     return Endpoint._track_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 574, in _track_costs
#     result: T = __func(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\llms\callbacks.py", line 219, in wrapped_llm_predict
#     f_return_val = f(_self, *args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\llms\langchain\base.py", line 90, in complete
#     output_str = self._llm.predict(prompt, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\_api\deprecation.py", line 145, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 1013, in predict
#     return self(text, stop=_stop, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\_api\deprecation.py", line 145, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 972, in __call__
#     self.generate(
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 714, in generate
#     output = self._generate_helper(
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 578, in _generate_helper
#     raise e
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 565, in _generate_helper
#     self._generate(
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_community\llms\openai.py", line 460, in _generate
#     response = completion_with_retry(
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_community\llms\openai.py", line 115, in completion_with_retry
#     return llm.client.create(**kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 668, in tru_wrapper
#     response = func(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\_utils\_utils.py", line 275, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\resources\completions.py", line 516, in create
#     return self._post(
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\_base_client.py", line 1208, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\_base_client.py", line 897, in request
#     return self._request(
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\_base_client.py", line 988, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.NotFoundError: Error code: 404 - {'error': {'message': 'The model `text-davinci-003` has been deprecated, learn more here: https://platform.openai.com/docs/deprecations', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
#
# Error calling wrapped function get_response.
# Traceback (most recent call last):
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 733, in tru_wrapper
#     rets, cost = Endpoint.track_all_costs_tally(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 496, in track_all_costs_tally
#     result, cbs = Endpoint.track_all_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 477, in track_all_costs
#     return Endpoint._track_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 574, in _track_costs
#     result: T = __func(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\response_synthesizers\compact_and_refine.py", line 38, in get_response
#     return super().get_response(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 831, in tru_wrapper
#     handle_done(rets=rets)
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 800, in handle_done
#     raise error
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 733, in tru_wrapper
#     rets, cost = Endpoint.track_all_costs_tally(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 496, in track_all_costs_tally
#     result, cbs = Endpoint.track_all_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 477, in track_all_costs
#     return Endpoint._track_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 574, in _track_costs
#     result: T = __func(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\response_synthesizers\refine.py", line 163, in get_response
#     response = self._give_response_single(
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\response_synthesizers\refine.py", line 217, in _give_response_single
#     program(
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\response_synthesizers\refine.py", line 68, in __call__
#     answer = self._llm.predict(
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\llms\llm.py", line 257, in predict
#     response = self.complete(formatted_prompt, formatted=True)
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 831, in tru_wrapper
#     handle_done(rets=rets)
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 800, in handle_done
#     raise error
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 733, in tru_wrapper
#     rets, cost = Endpoint.track_all_costs_tally(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 496, in track_all_costs_tally
#     result, cbs = Endpoint.track_all_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 477, in track_all_costs
#     return Endpoint._track_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 574, in _track_costs
#     result: T = __func(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\llms\callbacks.py", line 219, in wrapped_llm_predict
#     f_return_val = f(_self, *args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\llms\langchain\base.py", line 90, in complete
#     output_str = self._llm.predict(prompt, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\_api\deprecation.py", line 145, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 1013, in predict
#     return self(text, stop=_stop, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\_api\deprecation.py", line 145, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 972, in __call__
#     self.generate(
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 714, in generate
#     output = self._generate_helper(
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 578, in _generate_helper
#     raise e
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 565, in _generate_helper
#     self._generate(
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_community\llms\openai.py", line 460, in _generate
#     response = completion_with_retry(
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_community\llms\openai.py", line 115, in completion_with_retry
#     return llm.client.create(**kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 668, in tru_wrapper
#     response = func(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\_utils\_utils.py", line 275, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\resources\completions.py", line 516, in create
#     return self._post(
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\_base_client.py", line 1208, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\_base_client.py", line 897, in request
#     return self._request(
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\_base_client.py", line 988, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.NotFoundError: Error code: 404 - {'error': {'message': 'The model `text-davinci-003` has been deprecated, learn more here: https://platform.openai.com/docs/deprecations', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
#
# Error calling wrapped function query.
# Traceback (most recent call last):
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 733, in tru_wrapper
#     rets, cost = Endpoint.track_all_costs_tally(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 496, in track_all_costs_tally
#     result, cbs = Endpoint.track_all_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 477, in track_all_costs
#     return Endpoint._track_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 574, in _track_costs
#     result: T = __func(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\base\base_query_engine.py", line 40, in query
#     return self._query(str_or_query_bundle)
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\query_engine\retriever_query_engine.py", line 187, in _query
#     response = self._response_synthesizer.synthesize(
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\response_synthesizers\base.py", line 195, in synthesize
#     response_str = self.get_response(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 831, in tru_wrapper
#     handle_done(rets=rets)
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 800, in handle_done
#     raise error
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 733, in tru_wrapper
#     rets, cost = Endpoint.track_all_costs_tally(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 496, in track_all_costs_tally
#     result, cbs = Endpoint.track_all_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 477, in track_all_costs
#     return Endpoint._track_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 574, in _track_costs
#     result: T = __func(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\response_synthesizers\compact_and_refine.py", line 38, in get_response
#     return super().get_response(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 831, in tru_wrapper
#     handle_done(rets=rets)
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 800, in handle_done
#     raise error
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 733, in tru_wrapper
#     rets, cost = Endpoint.track_all_costs_tally(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 496, in track_all_costs_tally
#     result, cbs = Endpoint.track_all_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 477, in track_all_costs
#     return Endpoint._track_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 574, in _track_costs
#     result: T = __func(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\response_synthesizers\refine.py", line 163, in get_response
#     response = self._give_response_single(
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\response_synthesizers\refine.py", line 217, in _give_response_single
#     program(
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\response_synthesizers\refine.py", line 68, in __call__
#     answer = self._llm.predict(
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\llms\llm.py", line 257, in predict
#     response = self.complete(formatted_prompt, formatted=True)
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 831, in tru_wrapper
#     handle_done(rets=rets)
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 800, in handle_done
#     raise error
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py", line 733, in tru_wrapper
#     rets, cost = Endpoint.track_all_costs_tally(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 496, in track_all_costs_tally
#     result, cbs = Endpoint.track_all_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 477, in track_all_costs
#     return Endpoint._track_costs(
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 574, in _track_costs
#     result: T = __func(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\llms\callbacks.py", line 219, in wrapped_llm_predict
#     f_return_val = f(_self, *args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\llama_index\llms\langchain\base.py", line 90, in complete
#     output_str = self._llm.predict(prompt, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\_api\deprecation.py", line 145, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 1013, in predict
#     return self(text, stop=_stop, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\_api\deprecation.py", line 145, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 972, in __call__
#     self.generate(
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 714, in generate
#     output = self._generate_helper(
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 578, in _generate_helper
#     raise e
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py", line 565, in _generate_helper
#     self._generate(
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_community\llms\openai.py", line 460, in _generate
#     response = completion_with_retry(
#   File "c:\Users\28263\anaconda3\lib\site-packages\langchain_community\llms\openai.py", line 115, in completion_with_retry
#     return llm.client.create(**kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py", line 668, in tru_wrapper
#     response = func(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\_utils\_utils.py", line 275, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\resources\completions.py", line 516, in create
#     return self._post(
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\_base_client.py", line 1208, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\_base_client.py", line 897, in request
#     return self._request(
#   File "c:\Users\28263\anaconda3\lib\site-packages\openai\_base_client.py", line 988, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.NotFoundError: Error code: 404 - {'error': {'message': 'The model `text-davinci-003` has been deprecated, learn more here: https://platform.openai.com/docs/deprecations', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
#
# Could not determine main output from None.
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[48], line 2
#       1 # Run evaluation on sample questions
# ----> 2 with tru_recorder_rag_basic as recording:
#       3     for question in honest_evals:
#       4         response = rag_basic.query(question)
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\app.py:965, in App.__exit__(self, exc_type, exc_value, exc_tb)
#     962 self.recording_contexts.reset(ctx.token)
#     964 if exc_type is not None:
# --> 965     raise exc_value
#     967 return
#
# Cell In[48], line 4
#       2 with tru_recorder_rag_basic as recording:
#       3     for question in honest_evals:
# ----> 4         response = rag_basic.query(question)
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py:831, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     826     # TODO(piotrm): need to track costs of awaiting the ret in the
#     827     # below.
#     829     return wrap_awaitable(rets, on_done=handle_done)
# --> 831 handle_done(rets=rets)
#     832 return rets
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py:787, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper.<locals>.handle_done(rets)
#     781     # If stack has only 1 thing on it, we are looking at a "root
#     782     # call". Create a record of the result and notify the app:
#     784     if len(stack) == 1:
#     785         # If this is a root call, notify app to add the completed record
#     786         # into its containers:
# --> 787         records[ctx] = ctx.app.on_add_record(
#     788             ctx=ctx,
#     789             func=func,
#     790             sig=sig,
#     791             bindings=bindings,
#     792             ret=rets,
#     793             error=error,
#     794             perf=Perf(start_time=start_time, end_time=end_time),
#     795             cost=cost,
#     796             existing_record=records.get(ctx)
#     797         )
#     799 if error is not None:
#     800     raise error
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\app.py:1039, in App.on_add_record(self, ctx, func, sig, bindings, ret, error, perf, cost, existing_record)
#    1036 if error is not None:
#    1037     # May block on DB.
#    1038     self._handle_error(record=record, error=error)
# -> 1039     raise error
#    1041 # Will block on DB, but not on feedback evaluation, depending on
#    1042 # FeedbackMode:
#    1043 record.feedback_and_future_results = self._handle_record(record=record)
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py:733, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     728 try:
#     729     # Using sig bind here so we can produce a list of key-value
#     730     # pairs even if positional arguments were provided.
#     731     bindings: BoundArguments = sig.bind(*args, **kwargs)
# --> 733     rets, cost = Endpoint.track_all_costs_tally(
#     734         func, *args, **kwargs
#     735     )
#     737 except BaseException as e:
#     738     error = e
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:496, in Endpoint.track_all_costs_tally(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     481 @staticmethod
#     482 def track_all_costs_tally(
#     483     __func: CallableMaybeAwaitable[A, T],
#    (...)
#     489     **kwargs
#     490 ) -> Tuple[T, Cost]:
#     491     """
#     492     Track costs of all of the apis we can currently track, over the
#     493     execution of thunk.
#     494     """
# --> 496     result, cbs = Endpoint.track_all_costs(
#     497         __func,
#     498         *args,
#     499         with_openai=with_openai,
#     500         with_hugs=with_hugs,
#     501         with_litellm=with_litellm,
#     502         with_bedrock=with_bedrock,
#     503         **kwargs
#     504     )
#     506     if len(cbs) == 0:
#     507         # Otherwise sum returns "0" below.
#     508         costs = Cost()
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:477, in Endpoint.track_all_costs(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     468         except Exception as e:
#     469             logger.debug(
#     470                 "Could not initialize endpoint %s. "
#     471                 "Possibly missing key(s). "
#    (...)
#     474                 e,
#     475             )
# --> 477 return Endpoint._track_costs(
#     478     __func, *args, with_endpoints=endpoints, **kwargs
#     479 )
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:574, in Endpoint._track_costs(_Endpoint__func, with_endpoints, *args, **kwargs)
#     571     callbacks.append(callback)
#     573 # Call the function.
# --> 574 result: T = __func(*args, **kwargs)
#     576 # Return result and only the callbacks created here. Outer thunks might
#     577 # return others.
#     578 return result, callbacks
#
# File c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\base\base_query_engine.py:40, in BaseQueryEngine.query(self, str_or_query_bundle)
#      38 if isinstance(str_or_query_bundle, str):
#      39     str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 40 return self._query(str_or_query_bundle)
#
# File c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\query_engine\retriever_query_engine.py:187, in RetrieverQueryEngine._query(self, query_bundle)
#     183 with self.callback_manager.event(
#     184     CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     185 ) as query_event:
#     186     nodes = self.retrieve(query_bundle)
# --> 187     response = self._response_synthesizer.synthesize(
#     188         query=query_bundle,
#     189         nodes=nodes,
#     190     )
#     192     query_event.on_end(payload={EventPayload.RESPONSE: response})
#     194 return response
#
# File c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\response_synthesizers\base.py:195, in BaseSynthesizer.synthesize(self, query, nodes, additional_source_nodes, **response_kwargs)
#     190     query = QueryBundle(query_str=query)
#     192 with self._callback_manager.event(
#     193     CBEventType.SYNTHESIZE, payload={EventPayload.QUERY_STR: query.query_str}
#     194 ) as event:
# --> 195     response_str = self.get_response(
#     196         query_str=query.query_str,
#     197         text_chunks=[
#     198             n.node.get_content(metadata_mode=MetadataMode.LLM) for n in nodes
#     199         ],
#     200         **response_kwargs,
#     201     )
#     203     additional_source_nodes = additional_source_nodes or []
#     204     source_nodes = list(nodes) + list(additional_source_nodes)
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py:831, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     826     # TODO(piotrm): need to track costs of awaiting the ret in the
#     827     # below.
#     829     return wrap_awaitable(rets, on_done=handle_done)
# --> 831 handle_done(rets=rets)
#     832 return rets
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py:800, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper.<locals>.handle_done(rets)
#     787         records[ctx] = ctx.app.on_add_record(
#     788             ctx=ctx,
#     789             func=func,
#    (...)
#     796             existing_record=records.get(ctx)
#     797         )
#     799 if error is not None:
# --> 800     raise error
#     802 return records
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py:733, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     728 try:
#     729     # Using sig bind here so we can produce a list of key-value
#     730     # pairs even if positional arguments were provided.
#     731     bindings: BoundArguments = sig.bind(*args, **kwargs)
# --> 733     rets, cost = Endpoint.track_all_costs_tally(
#     734         func, *args, **kwargs
#     735     )
#     737 except BaseException as e:
#     738     error = e
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:496, in Endpoint.track_all_costs_tally(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     481 @staticmethod
#     482 def track_all_costs_tally(
#     483     __func: CallableMaybeAwaitable[A, T],
#    (...)
#     489     **kwargs
#     490 ) -> Tuple[T, Cost]:
#     491     """
#     492     Track costs of all of the apis we can currently track, over the
#     493     execution of thunk.
#     494     """
# --> 496     result, cbs = Endpoint.track_all_costs(
#     497         __func,
#     498         *args,
#     499         with_openai=with_openai,
#     500         with_hugs=with_hugs,
#     501         with_litellm=with_litellm,
#     502         with_bedrock=with_bedrock,
#     503         **kwargs
#     504     )
#     506     if len(cbs) == 0:
#     507         # Otherwise sum returns "0" below.
#     508         costs = Cost()
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:477, in Endpoint.track_all_costs(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     468         except Exception as e:
#     469             logger.debug(
#     470                 "Could not initialize endpoint %s. "
#     471                 "Possibly missing key(s). "
#    (...)
#     474                 e,
#     475             )
# --> 477 return Endpoint._track_costs(
#     478     __func, *args, with_endpoints=endpoints, **kwargs
#     479 )
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:574, in Endpoint._track_costs(_Endpoint__func, with_endpoints, *args, **kwargs)
#     571     callbacks.append(callback)
#     573 # Call the function.
# --> 574 result: T = __func(*args, **kwargs)
#     576 # Return result and only the callbacks created here. Outer thunks might
#     577 # return others.
#     578 return result, callbacks
#
# File c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\response_synthesizers\compact_and_refine.py:38, in CompactAndRefine.get_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#      34 # use prompt helper to fix compact text_chunks under the prompt limitation
#      35 # TODO: This is a temporary fix - reason it's temporary is that
#      36 # the refine template does not account for size of previous answer.
#      37 new_texts = self._make_compact_text_chunks(query_str, text_chunks)
# ---> 38 return super().get_response(
#      39     query_str=query_str,
#      40     text_chunks=new_texts,
#      41     prev_response=prev_response,
#      42     **response_kwargs,
#      43 )
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py:831, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     826     # TODO(piotrm): need to track costs of awaiting the ret in the
#     827     # below.
#     829     return wrap_awaitable(rets, on_done=handle_done)
# --> 831 handle_done(rets=rets)
#     832 return rets
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py:800, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper.<locals>.handle_done(rets)
#     787         records[ctx] = ctx.app.on_add_record(
#     788             ctx=ctx,
#     789             func=func,
#    (...)
#     796             existing_record=records.get(ctx)
#     797         )
#     799 if error is not None:
# --> 800     raise error
#     802 return records
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py:733, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     728 try:
#     729     # Using sig bind here so we can produce a list of key-value
#     730     # pairs even if positional arguments were provided.
#     731     bindings: BoundArguments = sig.bind(*args, **kwargs)
# --> 733     rets, cost = Endpoint.track_all_costs_tally(
#     734         func, *args, **kwargs
#     735     )
#     737 except BaseException as e:
#     738     error = e
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:496, in Endpoint.track_all_costs_tally(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     481 @staticmethod
#     482 def track_all_costs_tally(
#     483     __func: CallableMaybeAwaitable[A, T],
#    (...)
#     489     **kwargs
#     490 ) -> Tuple[T, Cost]:
#     491     """
#     492     Track costs of all of the apis we can currently track, over the
#     493     execution of thunk.
#     494     """
# --> 496     result, cbs = Endpoint.track_all_costs(
#     497         __func,
#     498         *args,
#     499         with_openai=with_openai,
#     500         with_hugs=with_hugs,
#     501         with_litellm=with_litellm,
#     502         with_bedrock=with_bedrock,
#     503         **kwargs
#     504     )
#     506     if len(cbs) == 0:
#     507         # Otherwise sum returns "0" below.
#     508         costs = Cost()
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:477, in Endpoint.track_all_costs(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     468         except Exception as e:
#     469             logger.debug(
#     470                 "Could not initialize endpoint %s. "
#     471                 "Possibly missing key(s). "
#    (...)
#     474                 e,
#     475             )
# --> 477 return Endpoint._track_costs(
#     478     __func, *args, with_endpoints=endpoints, **kwargs
#     479 )
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:574, in Endpoint._track_costs(_Endpoint__func, with_endpoints, *args, **kwargs)
#     571     callbacks.append(callback)
#     573 # Call the function.
# --> 574 result: T = __func(*args, **kwargs)
#     576 # Return result and only the callbacks created here. Outer thunks might
#     577 # return others.
#     578 return result, callbacks
#
# File c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\response_synthesizers\refine.py:163, in Refine.get_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#     159 for text_chunk in text_chunks:
#     160     if prev_response is None:
#     161         # if this is the first chunk, and text chunk already
#     162         # is an answer, then return it
# --> 163         response = self._give_response_single(
#     164             query_str, text_chunk, **response_kwargs
#     165         )
#     166     else:
#     167         # refine response if possible
#     168         response = self._refine_response_single(
#     169             prev_response, query_str, text_chunk, **response_kwargs
#     170         )
#
# File c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\response_synthesizers\refine.py:217, in Refine._give_response_single(self, query_str, text_chunk, **response_kwargs)
#     213 if response is None and not self._streaming:
#     214     try:
#     215         structured_response = cast(
#     216             StructuredRefineResponse,
# --> 217             program(
#     218                 context_str=cur_text_chunk,
#     219                 **response_kwargs,
#     220             ),
#     221         )
#     222         query_satisfied = structured_response.query_satisfied
#     223         if query_satisfied:
#
# File c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\response_synthesizers\refine.py:68, in DefaultRefineProgram.__call__(self, *args, **kwds)
#      66     answer = answer.json()
#      67 else:
# ---> 68     answer = self._llm.predict(
#      69         self._prompt,
#      70         **kwds,
#      71     )
#      72 return StructuredRefineResponse(answer=answer, query_satisfied=True)
#
# File c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\llms\llm.py:257, in LLM.predict(self, prompt, **prompt_args)
#     255 else:
#     256     formatted_prompt = self._get_prompt(prompt, **prompt_args)
# --> 257     response = self.complete(formatted_prompt, formatted=True)
#     258     output = response.text
#     260 return self._parse_output(output)
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py:831, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     826     # TODO(piotrm): need to track costs of awaiting the ret in the
#     827     # below.
#     829     return wrap_awaitable(rets, on_done=handle_done)
# --> 831 handle_done(rets=rets)
#     832 return rets
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py:800, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper.<locals>.handle_done(rets)
#     787         records[ctx] = ctx.app.on_add_record(
#     788             ctx=ctx,
#     789             func=func,
#    (...)
#     796             existing_record=records.get(ctx)
#     797         )
#     799 if error is not None:
# --> 800     raise error
#     802 return records
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\instruments.py:733, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     728 try:
#     729     # Using sig bind here so we can produce a list of key-value
#     730     # pairs even if positional arguments were provided.
#     731     bindings: BoundArguments = sig.bind(*args, **kwargs)
# --> 733     rets, cost = Endpoint.track_all_costs_tally(
#     734         func, *args, **kwargs
#     735     )
#     737 except BaseException as e:
#     738     error = e
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:496, in Endpoint.track_all_costs_tally(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     481 @staticmethod
#     482 def track_all_costs_tally(
#     483     __func: CallableMaybeAwaitable[A, T],
#    (...)
#     489     **kwargs
#     490 ) -> Tuple[T, Cost]:
#     491     """
#     492     Track costs of all of the apis we can currently track, over the
#     493     execution of thunk.
#     494     """
# --> 496     result, cbs = Endpoint.track_all_costs(
#     497         __func,
#     498         *args,
#     499         with_openai=with_openai,
#     500         with_hugs=with_hugs,
#     501         with_litellm=with_litellm,
#     502         with_bedrock=with_bedrock,
#     503         **kwargs
#     504     )
#     506     if len(cbs) == 0:
#     507         # Otherwise sum returns "0" below.
#     508         costs = Cost()
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:477, in Endpoint.track_all_costs(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     468         except Exception as e:
#     469             logger.debug(
#     470                 "Could not initialize endpoint %s. "
#     471                 "Possibly missing key(s). "
#    (...)
#     474                 e,
#     475             )
# --> 477 return Endpoint._track_costs(
#     478     __func, *args, with_endpoints=endpoints, **kwargs
#     479 )
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:574, in Endpoint._track_costs(_Endpoint__func, with_endpoints, *args, **kwargs)
#     571     callbacks.append(callback)
#     573 # Call the function.
# --> 574 result: T = __func(*args, **kwargs)
#     576 # Return result and only the callbacks created here. Outer thunks might
#     577 # return others.
#     578 return result, callbacks
#
# File c:\Users\28263\anaconda3\lib\site-packages\llama_index\core\llms\callbacks.py:219, in llm_completion_callback.<locals>.wrap.<locals>.wrapped_llm_predict(_self, *args, **kwargs)
#     209 with wrapper_logic(_self) as callback_manager:
#     210     event_id = callback_manager.on_event_start(
#     211         CBEventType.LLM,
#     212         payload={
#    (...)
#     216         },
#     217     )
# --> 219     f_return_val = f(_self, *args, **kwargs)
#     220     if isinstance(f_return_val, Generator):
#     221         # intercept the generator and add a callback to the end
#     222         def wrapped_gen() -> CompletionResponseGen:
#
# File c:\Users\28263\anaconda3\lib\site-packages\llama_index\llms\langchain\base.py:90, in LangChainLLM.complete(self, prompt, formatted, **kwargs)
#      87 if not formatted:
#      88     prompt = self.completion_to_prompt(prompt)
# ---> 90 output_str = self._llm.predict(prompt, **kwargs)
#      91 return CompletionResponse(text=output_str)
#
# File c:\Users\28263\anaconda3\lib\site-packages\langchain_core\_api\deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py:1013, in BaseLLM.predict(self, text, stop, **kwargs)
#    1011 else:
#    1012     _stop = list(stop)
# -> 1013 return self(text, stop=_stop, **kwargs)
#
# File c:\Users\28263\anaconda3\lib\site-packages\langchain_core\_api\deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py:972, in BaseLLM.__call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#     965 if not isinstance(prompt, str):
#     966     raise ValueError(
#     967         "Argument `prompt` is expected to be a string. Instead found "
#     968         f"{type(prompt)}. If you want to run the LLM on multiple prompts, use "
#     969         "`generate` instead."
#     970     )
#     971 return (
# --> 972     self.generate(
#     973         [prompt],
#     974         stop=stop,
#     975         callbacks=callbacks,
#     976         tags=tags,
#     977         metadata=metadata,
#     978         **kwargs,
#     979     )
#     980     .generations[0][0]
#     981     .text
#     982 )
#
# File c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py:714, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, **kwargs)
#     698         raise ValueError(
#     699             "Asked to cache, but no cache found at `langchain.cache`."
#     700         )
#     701     run_managers = [
#     702         callback_manager.on_llm_start(
#     703             dumpd(self),
#    (...)
#     712         )
#     713     ]
# --> 714     output = self._generate_helper(
#     715         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     716     )
#     717     return output
#     718 if len(missing_prompts) > 0:
#
# File c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py:578, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     576     for run_manager in run_managers:
#     577         run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 578     raise e
#     579 flattened_outputs = output.flatten()
#     580 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File c:\Users\28263\anaconda3\lib\site-packages\langchain_core\language_models\llms.py:565, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     555 def _generate_helper(
#     556     self,
#     557     prompts: List[str],
#    (...)
#     561     **kwargs: Any,
#     562 ) -> LLMResult:
#     563     try:
#     564         output = (
# --> 565             self._generate(
#     566                 prompts,
#     567                 stop=stop,
#     568                 # TODO: support multiple run managers
#     569                 run_manager=run_managers[0] if run_managers else None,
#     570                 **kwargs,
#     571             )
#     572             if new_arg_supported
#     573             else self._generate(prompts, stop=stop)
#     574         )
#     575     except BaseException as e:
#     576         for run_manager in run_managers:
#
# File c:\Users\28263\anaconda3\lib\site-packages\langchain_community\llms\openai.py:460, in BaseOpenAI._generate(self, prompts, stop, run_manager, **kwargs)
#     448     choices.append(
#     449         {
#     450             "text": generation.text,
#    (...)
#     457         }
#     458     )
#     459 else:
# --> 460     response = completion_with_retry(
#     461         self, prompt=_prompts, run_manager=run_manager, **params
#     462     )
#     463     if not isinstance(response, dict):
#     464         # V1 client returns the response in an PyDantic object instead of
#     465         # dict. For the transition period, we deep convert it to dict.
#     466         response = response.dict()
#
# File c:\Users\28263\anaconda3\lib\site-packages\langchain_community\llms\openai.py:115, in completion_with_retry(llm, run_manager, **kwargs)
#     113 """Use tenacity to retry the completion call."""
#     114 if is_openai_v1():
# --> 115     return llm.client.create(**kwargs)
#     117 retry_decorator = _create_retry_decorator(llm, run_manager=run_manager)
#     119 @retry_decorator
#     120 def _completion_with_retry(**kwargs: Any) -> Any:
#
# File c:\Users\28263\anaconda3\lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:668, in Endpoint.wrap_function.<locals>.tru_wrapper(*args, **kwargs)
#     658 logger.debug(
#     659     "Calling instrumented method %s of type %s, "
#     660     "iscoroutinefunction=%s, "
#    (...)
#     663     inspect.isasyncgenfunction(func)
#     664 )
#     666 # Get the result of the wrapped function:
# --> 668 response = func(*args, **kwargs)
#     670 bindings = inspect.signature(func).bind(*args, **kwargs)
#     672 # Get all of the callback classes suitable for handling this
#     673 # call. Note that we stored this in the INSTRUMENT attribute of
#     674 # the wrapper method.
#
# File c:\Users\28263\anaconda3\lib\site-packages\openai\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File c:\Users\28263\anaconda3\lib\site-packages\openai\resources\completions.py:516, in Completions.create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     488 @required_args(["model", "prompt"], ["model", "prompt", "stream"])
#     489 def create(
#     490     self,
#    (...)
#     514     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     515 ) -> Completion | Stream[Completion]:
# --> 516     return self._post(
#     517         "/completions",
#     518         body=maybe_transform(
#     519             {
#     520                 "model": model,
#     521                 "prompt": prompt,
#     522                 "best_of": best_of,
#     523                 "echo": echo,
#     524                 "frequency_penalty": frequency_penalty,
#     525                 "logit_bias": logit_bias,
#     526                 "logprobs": logprobs,
#     527                 "max_tokens": max_tokens,
#     528                 "n": n,
#     529                 "presence_penalty": presence_penalty,
#     530                 "seed": seed,
#     531                 "stop": stop,
#     532                 "stream": stream,
#     533                 "suffix": suffix,
#     534                 "temperature": temperature,
#     535                 "top_p": top_p,
#     536                 "user": user,
#     537             },
#     538             completion_create_params.CompletionCreateParams,
#     539         ),
#     540         options=make_request_options(
#     541             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     542         ),
#     543         cast_to=Completion,
#     544         stream=stream or False,
#     545         stream_cls=Stream[Completion],
#     546     )
#
# File c:\Users\28263\anaconda3\lib\site-packages\openai\_base_client.py:1208, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1194 def post(
#    1195     self,
#    1196     path: str,
#    (...)
#    1203     stream_cls: type[_StreamT] | None = None,
#    1204 ) -> ResponseT | _StreamT:
#    1205     opts = FinalRequestOptions.construct(
#    1206         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1207     )
# -> 1208     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\28263\anaconda3\lib\site-packages\openai\_base_client.py:897, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     888 def request(
#     889     self,
#     890     cast_to: Type[ResponseT],
#    (...)
#     895     stream_cls: type[_StreamT] | None = None,
#     896 ) -> ResponseT | _StreamT:
# --> 897     return self._request(
#     898         cast_to=cast_to,
#     899         options=options,
#     900         stream=stream,
#     901         stream_cls=stream_cls,
#     902         remaining_retries=remaining_retries,
#     903     )
#
# File c:\Users\28263\anaconda3\lib\site-packages\openai\_base_client.py:988, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     985         err.response.read()
#     987     log.debug("Re-raising status error")
# --> 988     raise self._make_status_error_from_response(err.response) from None
#     990 return self._process_response(
#     991     cast_to=cast_to,
#     992     options=options,
#    (...)
#     995     stream_cls=stream_cls,
#     996 )
#
# NotFoundError: Error code: 404 - {'error': {'message': 'The model `text-davinci-003` has been deprecated, learn more here: https://platform.openai.com/docs/deprecations', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}

# %%
# get leaderboard
tru.get_leaderboard(app_ids=["1) Basic RAG - Honest Eval"])
# Out:
# Empty DataFrame
# Columns: [latency, total_cost]
# Index: []
